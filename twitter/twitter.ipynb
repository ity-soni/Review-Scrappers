# %%
import tweepy
import configparser

config = configparser.ConfigParser()
config.read('config-academic.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']


## authentication 
auth = tweepy.OAuthHandler(api_key,api_key_secret)
auth.set_access_token(access_token,access_token_secret)


api = tweepy.API(auth)

public_tweets=api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# 😇 @Prowsey16 just keeps running and running! 🏃‍♂️
#
# @SouthamptonFC https://t.co/QO24hi3YGN
# What do you make of @alanshearer's picks? 🤔 https://t.co/lCV0tQgDtA
# RT @LCFC: Pace, precision, then passion 🔵 🎞️ https://t.co/xUoxD8MbZC
# Match official appointments for #PL Matchweek 23 (11-15 Feb) have been confirmed
#
# ➡️ https://t.co/rkd0Y4nv3t https://t.co/UpEpkXiHqQ
# A @SpursOfficial ✨ legend ✨
#
# #PL | @HKane https://t.co/X1Jl3XUeP4
# RT @LUFC: #LUFC can confirm head coach Jesse Marsch has been relieved of his duties
# 👀 COMING SOON 👀
#
# Watch the inaugural #ePLInvitational LIVE, featuring all 40 of this year's finalists https://t.co/a6A5w6sejk
# RT @Wolves: Could watch this on repeat, tbh 😍 https://t.co/TeHui5xgDP
# Things are looking up in Nottingham 📈
#
# @NFFC lead the way in 2023 👏 https://t.co/yPnyMMvejN
# Harry Kane has scored against every club he's faced in the #PL 😱
#
# @HKane  | @SpursOfficial https://t.co/r9t4l661Ty
# Where's your team? 😅 https://t.co/bO0ZaHJ8KA
# ...

# %%
api.search_tweets('@sofistadium')
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fef897798b0>, _json={'created_at': 'Mon Feb 06 21:42:08 +0000 2023', 'id': 1622712269468536832, 'id_str': '1622712269468536832', 'text': '@MattStaffordQB1 @SoFiStadium @RamsNFL Josh Allen would say otherwise lol just kidding  GO BILLS', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'MattStaffordQB1', 'name': 'LA RAMS FOOTBALL', 'id': 1433937060218368000, 'id_str': '1433937060218368000', 'indices': [0, 16]}, {'screen_name': 'SoFiStadium', 'name': 'SoFi Stadium', 'id': 1121893049544527873, 'id_str': '1121893049544527873', 'indices': [17, 29]}, {'screen_name': 'RamsNFL', 'name': 'Los Angeles Rams', 'id': 24109979, 'id_str': '24109979', 'indices': [30, 38]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1622702144729272321, 'in_reply_to_stat
# ...

# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob
  
class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        
        config = configparser.ConfigParser()
        config.read('config.ini')

        api_key = config['twitter']['api_key']
        api_key_secret = config['twitter']['api_key_secret']

        access_token = config['twitter']['access_token']
        access_token_secret = config['twitter']['access_token_secret']


        ## authentication 
        auth = tweepy.OAuthHandler(api_key,api_key_secret)
        auth.set_access_token(access_token,access_token_secret)


        self.api = tweepy.API(auth)
        
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'XXXXXXXXXXXXXXXXXXXXXXXX'
        consumer_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXX'
        access_token = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXX'
        access_token_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXX'
  
        # attempt authentication
        # try:
        #     # create OAuthHandler object
        #     self.auth = OAuthHandler(consumer_key, consumer_secret)
        #     # set access token and secret
        #     self.auth.set_access_token(access_token, access_token_secret)
        #     # create tweepy API object to fetch tweets
        #     self.api = tweepy.API(self.auth)
        # except:
        #     print("Error: Authentication Failed")
  
    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
  
    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity > 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'
  
    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []
  
        # try:
        # call twitter api to fetch tweets
        print("Heeeeee")
        fetched_tweets = self.api.search_tweets(q = query, count = count)
        print('Wbh')
        # parsing tweets one by one
        for tweet in fetched_tweets:
            # empty dictionary to store required params of a tweet
            parsed_tweet = {}

            # saving text of tweet
            parsed_tweet['text'] = tweet.text
            # saving sentiment of tweet
            parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)
            print("Here")
            # appending parsed tweet to tweets list
            # if tweet.retweet_count > 0:
                # if tweet has retweets, ensure that it is appended only once
                # if parsed_tweet not in tweets:
                    # tweets.append(parsed_tweet)
            # else:
                # tweets.append(parsed_tweet)
            tweets.append(parsed_tweet)
            # return parsed tweets
        return tweets
  
        # except:
        #     print("Error")
    
        # except tweepy.TweepError as e:
            # print error (if any)
            # print("Error : " + str(e))
  
# def main():
#     # creating object of TwitterClient Class
#     api = TwitterClient()
#     # calling function to get tweets
#     tweets = api.get_tweets(query = 'SofiStadium', count = 200)
  
#     # picking positive tweets from tweets
#     ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
#     # percentage of positive tweets
#     print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets)))
#     # picking negative tweets from tweets
#     ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
#     # percentage of negative tweets
#     print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets)))
#     # percentage of neutral tweets
#     print("Neutral tweets percentage: {} % \
#         ".format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets)))
  
#     # printing first 5 positive tweets
#     print("\n\nPositive tweets:")
#     for tweet in ptweets[:10]:
#         print(tweet['text'])
  
#     # printing first 5 negative tweets
#     print("\n\nNegative tweets:")
#     for tweet in ntweets[:10]:
#         print(tweet['text'])
  
# if __name__ == "__main__":
#     # calling main function
#     main()

api = TwitterClient()
tweets = api.get_tweets(query = 'SofiStadium', count = 400)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qd/k5jr26ss2wdf84q7ktnkgshc0000gn/T/ipykernel_37407/1871336641.py in <module>
#       2 import tweepy
#       3 from tweepy import OAuthHandler
# ----> 4 from textblob import TextBlob
#       5
#       6 class TwitterClient(object):
#
# ModuleNotFoundError: No module named 'textblob'

# %%
len(tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qd/k5jr26ss2wdf84q7ktnkgshc0000gn/T/ipykernel_37407/2246039635.py in <module>
# ----> 1 len(tweets)
#
# NameError: name 'tweets' is not defined

# %%
# tweepy.Cursor(api.get_tweets,q='sofistadium',count=1000, lang="en", since_id=0).items()

# %%
# tweetstweets = tweepy.Paginator(api.search_all_tweets, query='sofistadium').flatten(limit=1000)

# %%
import tweepy
import configparser
import time

config = configparser.ConfigParser()
config.read('config-academic.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

access_token = config['twitter']['access_token']
access_token_secret = config['twitter']['access_token_secret']
# bearer_token = config['twitter']['bearer_token']
bearer_token = "AAAAAAAAAAAAAAAAAAAAAFpDkQEAAAAAF1jm1uj5JK8D6vIQhK3VTNZSWA4%3Db18VcZkOXKbfbZLiqbiq23Z22uUnKpkZUq8UjvrTiLB58Evkkp"


#Put your Bearer Token in the parenthesis below
client = tweepy.Client(bearer_token=bearer_token)

"""
If you don't understand search queries, there is an excellent introduction to it here: 
https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/5-how-to-write-search-queries.md
"""

# Get tweets that contain the string 'sofistadium'
# -is:retweet means I don't wantretweets
# lang:en is asking for the tweets to be in english



query = '@SoFiStadium -is:retweet lang:en'
tweets = tweepy.Paginator(client.search_all_tweets, query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=50000)
# tweets = tweepy.Paginator(client.search_recent_tweets, query=query, tweet_fields=['context_annotations', 'created_at']).flatten(limit=100000)


i=0
t=[]
for tweet in tweets:
    # print(i)
    if i%100==0:
        time.sleep(2)
    d={}
    d['text']=tweet.text
    d['created_at']=tweet.created_at
    # print(d['text'])
    if len(tweet.context_annotations) > 0:
        d['context_annotations']=tweet.context_annotations
        # print(d['context_annotations'])
    # print(d['created_at'])
    i+=1
    if i==5000:
        time.sleep(15*60)
    t.append(d)
    

query1 = '#sofistadium -is:retweet lang:en'
tweets1 = tweepy.Paginator(client.search_all_tweets, query=query, tweet_fields=['context_annotations', 'created_at'], max_results=100).flatten(limit=50000)
# tweets = tweepy.Paginator(client.search_recent_tweets, query=query, tweet_fields=['context_annotations', 'created_at']).flatten(limit=100000)


for tweet1 in tweets1:
    # print(i)
    if i%100 ==0:
        time.sleep(1.5)
    d={}
    d['text']=tweet1.text
    d['created_at']=tweet1.created_at
    # print(d['text'])
    if len(tweet1.context_annotations) > 0:
        d['context_annotations']=tweet1.context_annotations
        # print(d['context_annotations'])
    # print(d['created_at'])
    i+=1
    if i==10000:
        time.sleep(15*60)
    t.append(d)    

# t=[]
# for tweet in tweets:
#             # empty dictionary to store required params of a tweet
#             parsed_tweet = {}

#             # saving text of tweet
#             parsed_tweet['text'] = tweet.text
#             # saving sentiment of tweet
#             parsed_tweet['sentiment'] = get_tweet_sentiment(tweet.text)
#             print("Here")
#             # appending parsed tweet to tweets list
#             # if tweet.retweet_count > 0:
#                 # if tweet has retweets, ensure that it is appended only once
#                 # if parsed_tweet not in tweets:
#                     # tweets.append(parsed_tweet)
#             # else:
#                 # tweets.append(parsed_tweet)
#             t.append(parsed_tweet)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /var/folders/qd/k5jr26ss2wdf84q7ktnkgshc0000gn/T/ipykernel_37407/1836776236.py in <module>
#      59
#      60
# ---> 61 for tweet1 in tweets1:
#      62     # print(i)
#      63     if i%100 ==0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/pagination.py in flatten(self, limit)
#      65
#      66         count = 0
# ---> 67         for response in PaginationIterator(
#      68             self.method, *self.args, **self.kwargs
#      69         ):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/tweepy/pagination.py in __next__(self)
#     124             self.kwargs["pagination_token"] = pagination_token
#     125
# --> 126         response = self.method(*self.args, **self.kwargs)
#     127
#     128         if isinstance(response, Response):
#
# ...

# %%
len(t)
# Out:
# 3999

# %%
t[:1]
# Out:
# [{'text': '@MattStaffordQB1 @SoFiStadium @RamsNFL Josh Allen would say otherwise lol just kidding  GO BILLS',
#   'created_at': datetime.datetime(2023, 2, 6, 21, 42, 8, tzinfo=datetime.timezone.utc),
#   'context_annotations': [{'domain': {'id': '3',
#      'name': 'TV Shows',
#      'description': 'Television shows from around the world'},
#     'entity': {'id': '10000612773',
#      'name': 'NFL Football',
#      'description': 'Football action from around the National Football League.'}},
#    {'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '984774070100086784',
#      'name': 'Josh Allen',
#      'description': 'Josh Allen, 2018 NFL Draft'}},
#    {'domain': {'id': '11',
#      'name': 'Sport',
#      'description': 'Types of sports, like soccer and basketball'},
#     'entity': {'id': '689566306014617600', 'name': 'American football'}},
#    {'domain': {'id': '12',
# ...

# %%
import pandas as pd
df=pd.DataFrame.from_dict(t)

# %%
df.columns
# Out:
# Index(['text', 'created_at', 'context_annotations'], dtype='object')

# %%
df.to_csv('twitter_reviews.csv')

# %%
for a in tweets:
    break

# %%
b.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [32], line 1
# ----> 1 b.text
#
# NameError: name 'b' is not defined

# %%
for b in a:
    print(b)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [81], in <cell line: 1>()
# ----> 1 t.text
#
# AttributeError: 'list' object has no attribute 'text'

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qd/k5jr26ss2wdf84q7ktnkgshc0000gn/T/ipykernel_6311/3208813603.py in <module>
# ----> 1 import keras
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/__init__.py in <module>
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/models/__init__.py in <module>
#      16
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# ~/opt/anaconda3/lib/python3.9/site-packages/keras/engine/functional.py in <module>
#      22 import warnings
#      23
# ---> 24 import tensorflow.compat.v2 as tf
#      25
# ...
